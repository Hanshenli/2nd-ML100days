# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
"""作業1：
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
1. 你選的這組資料為何重要
House Prices;提供房價以外的其他變數可供參考
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
Dean De Cock 大學教授 
3. 蒐集而來的資料型態為何
結構化資料
4. 這組資料想解決的問題如何評估
將預測的房價與實值房價做Root-Mean-Squared-Error (RMSE) 


作業2：
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
減少空車時間及接客距離，便有效利用資源，開發潛在顧客
可能在不同的區域、時間配置的車子數要有所更動
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
叫車紀錄:叫車地點、目的地、司機位置
3. 蒐集而來的資料型態為何
結構化資料
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
將叫車狀況重新與空車媒合，檢示其空間時間是否降低"""
# Out:
# '作業1：\n請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：\n1. 你選的這組資料為何重要\nHouse Prices;提供房價以外的其他變數可供參考\n2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)\nDean De Cock 大學教授 \n3. 蒐集而來的資料型態為何\n結構化資料\n4. 這組資料想解決的問題如何評估\n將預測的房價與實值房價做Root-Mean-Squared-Error (RMSE) \n\n\n作業2：\n想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：\n1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)\n減少空車時間及接客距離，便有效利用資源，開發潛在顧客\n可能在不同的區域、時間配置的車子數要有所更動\n2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)\n叫車紀錄:叫車地點、目的地、司機位置\n3. 蒐集而來的資料型態為何\n結構化資料\n4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)\n將叫車狀況重新與空車媒合，檢示其空間時間是否降低'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):

   
    mse  = sum((y - y_hat)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    
    mae  = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 230.889
# The Mean absolute error is 11.891
